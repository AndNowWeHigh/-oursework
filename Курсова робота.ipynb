# %% [markdown]
# <center>
# <img src="photo/1.png">
#
# <span style="font-size:18px;">
#     <center>
# Міністерство освіти і науки, молоді та спорту України<br>
# Національний технічний університет України "Київський політехнічний інститут імені Ігоря Сікорського"<br>
# Фізико-технічний інститут
#     </center>
# </span>
#
# # Курсова робота
# ## Аналіз даних за допомогою Python та бібліотеки Pandas
#
#
# **Виконав:**
# Зіневич Валентин, групи ФІ-21, НН ФТІ
#
# **Перевірив:**
#
#
# </center>

# %% [markdown]
# <center>
# <h1>Частина 1</h1>
# </center>
#
# <h2>(До 60 балів) Знайомство з можливостями Anaconda/IPython
# Notebook</h2><br>
#
# <span style="font-size:22px;">
#     <strong>Мета:</strong> Вивчення основних принципів роботи та використання програмних
# компонентів <em>Anaconda</em>. <strong>Інсталяція.</strong> Дослідження можливостей <em>IPython
# Notebook</em>. Підготовка розділу 1 пояснювальної записки про зроблену
# роботу — опис інсталяції, можливостей використання та їх ілюстрація.
# </span>

# %% [markdown]
# <span style="font-size:24px;">
# <strong>Вступ</strong><br>
# </span>
#
#
# <span style="font-size:18px;">
# <u>Ipython Notebook</u> - це середовище розробки, що дає можливості для інтерактивної та ітеративної
# розробки проектів, пов’язаних з Data Science. Notebook інтегрує код та результати його виконання в
# один файл разом з графіками, текстом, математичними виразами та іншими можливими видами
# представлення інформації.<br>
# </span>
# <br>
# <span style="font-size:18px;">
# <u>Jupyter Notebook</u> - неймовірно потужний інструмент для інтерактивної розробки
# та подання проектів в області наук про дані. Це зручний інструмент для створення
# аналітичних звітів, що дозволяє одночасно зберігати разом код, формули,
# зображення, коментарі, результати і графіки.<br>
# </span>
# <br>
# <span style="font-size:18px;">
# <u>Anaconda Navigator</u> - це настільний графічний інтерфейс користувача (GUI), що входить до складу дистрибутива Anaconda, який дозволяє запускати програми та керувати пакунками conda, середовищами і каналами без використання команд інтерфейсу командного рядка (CLI).<br>
# </span>
# <br>
# <span style="font-size:18px;">
# <u>Spyder</u> - відкрите крос-платформне інтегроване середовище розробки (IDE) для наукового програмування мовою Python. Spyder інтегрується з рядом відомих пакетів в науковому стеку Python, включаючи NumPy, SciPy, Matplotlib, Pandas, IPython, SymPy і Cython, а також інше програмне забезпечення з відкритим кодом. Поширюється безкоштовно, як проєкт з вихідним кодом під ліцензією MIT License.<br>
# </span>
#
# <br>
# <span style="font-size:18px;">
#     <u>Anaconda Powershell Prompt</u> та <u>Anaconda Prompt</u> - це інструменти, які надають інтерфейс командного рядка для управління середовищем Python, пакетами та іншими інструментами, які постачаються з Anaconda. З його допомогою ви можете виконувати команди для інсталяції, оновлення та керування пакетами, а також створювати та управляти віртуальними середовищами. Основна різниця цих інструментів поялгає в тому, де вони запустають команди conda:
#     <br><li>Anaconda Prompt - cmd.exe</li>
#     <br><li>Anaconda Powershell Prompt - powershell.exe</li>
#
# </span>

# %% [markdown]
# <span style="font-size:24px;">
# <strong>Інсталація</strong> Anaconda Distribution:
#
# </span>

# %% [markdown]
# <span style="font-size:18px;">
# 1.1 Переходимо за <a href="https://www.anaconda.com/">посилання</a> та натискаємо "Free Download"
# </span>

# %% [markdown]
# <img src="photo/2.png">

# %% [markdown]
# <span style="font-size:18px;">
# 1.2 Завантажуємо та відкриваємо інсталятор
# </span>

# %% [markdown]
# <img src="photo/3.png">

# %% [markdown]
# <img src="photo/4.png">

# %% [markdown]
# <span style="font-size:18px;">
#     2. відкриваємо <em>Anaconda Navigator</em> та завантажуємо(install) <em>Jupyter Notebook</em>(у мене вже встановлений)
# </span>

# %% [markdown]
# <img src="photo/5.png">

# %% [markdown]
# <span style="font-size:18px;">3. Відкриваємо <em>Jupyter Notebook</em> та ми бачимо дерево файлів</span>

# %% [markdown]
# <img src="photo/6.1.png">

# %% [markdown]
# <span style="font-size:18px">Але ми можемо змінити директорію, яка буде відкриватися при запуску</span><br>
# <span style="font-size:18px"><strong>1.</strong> Натиснути на ярлик <em>Jupyter Notebook</em>  правою клавішою миші => <strong>2.</strong> "Властивості" => <strong>3.</strong> Та змінти віділене синім (фото👇🏻) на директорію, яка повинна відкриватися при запусту <em>Jupyter Notebook</em> </span>

# %% [markdown]
# <img src="photo/6.png">

# %% [markdown]
# <span style="font-size:24px;">Можливості <em>Jupyter Notebook</em>:</span>

# %% [markdown]
# <span style="font-size:18px;">
# <li>Створення\Редагування\Тестування коду Python в реальному часі(та декілька інших мов програмування)</li>
# <li>Кольорове виділення синтексису</li>
# <li>Візуалізація\Аналіз\Обробка даних</li>
# <li>Підримує декілька типів розмітки Markdown\HTML\LaTex</li>
# </span>

# %% [markdown]
# # Приклад використання Markdown розмітки
#
# # Заголовок 1
#
# ## Заголовок 2
#
# ### Заголовок 3
#
# Текст може бути *курсивним*, **жирним**, або `моноширинним`.
#
# #### Маркований список:
# - Пункт 1
# - Пункт 2
# - Пункт 3
#
# #### Нумерований список:
# 1. Елемент 1
# 2. Елемент 2
# 3. Елемент 3
#
# ### Посилання
# [посилання](https://..)
#
# ### Зображення
# ![зображення](https://..)
#
#
# <h1>Приклад використання HTML розмітки</h1>
#
#   <h1>Заголовок 1</h1>
#
#   <h2>Заголовок 2</h2>
#
#   <h3>Заголовок 3</h3>
#
#   <p>Текст може бути <em>курсивним</em>, <strong>жирним</strong>, або <code>моноширинним</code>.</p>
#
#   <h4>Маркований список:</h4>
#   <ul>
#     <li>Пункт 1</li>
#     <li>Пункт 2</li>
#     <li>Пункт 3</li>
#   </ul>
#
#   <h4>Нумерований список:</h4>
#   <ol>
#     <li>Елемент 1</li>
#     <li>Елемент 2</li>
#     <li>Елемент 3</li>
#   </ol>
#
#   <h3>Посилання</h3>
#   <p><a href="https://..">Приклад посилання</a></p>
#
#   <h3>Зображення</h3>
#   <p><img src="https://.."></p>
#
# <h1>Приклад використання LaTex розмітки</h1>
#
# $$
# \bar{X_{std}} = \frac{1}{\sigma} (X - \mu)
# $$
#
# $$
# \mu = \sum p_i X_i  {-де  p_i-ймовірність \hspace{0.25cm} появи \hspace{0.25cm} елементу X_i}
# $$
#
# $$
# \sigma = \sqrt{\frac{\sum_{}{} (X_i - \bar{X})}{n-1}}
# $$

# %% [markdown]
# <center>
# <h1>Частина 2</h1>
# </center>
#
# <h2>(До 30 балів)Виконання та підготовка розділу 2 пояснювальної записки</h2><br>
#
# <span style="font-size:22px;">
#     <strong>Мета Частини 2:</strong> Отримати досвід використання основних засобів аналізу та візуалізації даних у середовищі <em>IPython Notebook</em> на модельних наборах даних.
# </span>

# %% [markdown]
# <span style="font-size:18px;"> Набір даних було завантажено з репозиторію машинного навчання UCI. Набір даних стосується червоного та білого варіантів португальського вина "Vinho Verde". Джерело [Cortez et al., 2009]. Через проблеми конфіденційності та логістики доступні лише фізико-хімічні (вхідні) та сенсорні (вихідні) змінні (наприклад, немає даних про типи винограду, марку вина, ціну продажу вина тощо). Цей набір даних можна розглядати як завдання класифікації або регресії. Класи впорядковані і не збалансовані (наприклад, нормальних вин більше, ніж відмінних чи поганих).</span><br>
# <span style="font-size:18px;">
#     Датасет має колонки 1 категоріальну та 12 числових колонок:
# </span><br>
# <li>type => тип</li>
# <li>fixed acidity => фіксована кислотність </li>
# <li>volatile acidity => летюча кислотність</li>
# <li>citric acid => лимонна кислота</li>
# <li>residual sugar => залишковий цукор</li>
# <li>chlorides => хлориди</li>
# <li>free sulfur dioxide => вільний діоксид сірки</li>
# <li>total sulfur dioxide => загальний діоксид сірки</li>
# <li>density => густина</li>
# <li>pH => водневий показник </li>
# <li>sulphates => сульфати</li>
# <li>alcohol => спирт</li>
# <li>quality => якість</li>

# %% [markdown]
# <span style="font-size:24px;">
#     Імпортуємо необхідні для подальної роботи пакети
# </span>

# %%
import pandas as pd
from pandas.io.formats.style import Styler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


path_dataset = 'winequalityN.csv'

# %% [markdown]
# <h2>3</h2>
# <br>
# <span style="font-size:18px;">
#     Зчитуємо та перетворюємо .csv файл на dataframe
# </span>

# %%
data = pd.read_csv(path_dataset)
# Копіюємо дані для використання в 8 завданні 
c_data = data.copy()
c_data
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data.head() #перші 5 рядків
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %% [markdown]
# <h2>2.1</h2>
# <br>
# <span style="font-size:18px;">
#     Дізнаємося чи є пропущені значення та їх кількість
# </span>

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %% [markdown]
# <h2>2.2</h2>
# <br>
# <span style="font-size:18px;">
#     За умови якщо у нас є пропущені значення, то пропущені значення будуть заповнені значеннями з попереднього непропущеного рядка.
# </span>

# %%
if data.isnull().values.any():
    data = data.ffill()  #data.bfill() пропущені значення будуть замінені наступного непропущеного рядка

# %%
data.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# <h2>4.1</h2>
# <br>
# <span style='font-size:18px;'>Представити його у матричному вигляді. Відобразити 10 елементів для 4-ох ознак Виділити
# зеленим кольором максимальні елементи в таблиці, а червоним мінімальні для цих 10-ти
# елементів.</span>

# %%
# 2.4
df = pd.DataFrame(data)
# Вибір стовпців + перші 10 значень
df = df[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar']][0:10]

# Функція для виділення максимального та мінімального значення в рядку
def color_max_min(s):
    is_max = s == s.max()
    is_min = s == s.min()
    
    max_style = []
    for v in is_max:
        if v:
            max_style.append('background-color: green')
        else:
            max_style.append('')
    print(max_style)
    
    min_style = []
    for v in is_min:
        if v:
            min_style.append('background-color: red')
        else:
            min_style.append('')  
    print( min_style)
    
    return [max_style[i] + min_style[i] for i in range(len(s))]

# Стилізуємо dataframe
styled_df = df.style.apply(color_max_min)


# Відображення dataframe
styled_df
# Out:
# ['', '', 'background-color: green', '', '', 'background-color: green', '', '', '', 'background-color: green']
# ['', '', '', '', '', '', 'background-color: red', '', '', '']
# ['', '', '', '', '', '', 'background-color: green', '', '', '']
# ['', '', '', '', '', '', '', '', '', 'background-color: red']
# ['', '', '', '', '', '', '', '', '', 'background-color: green']
# ['', '', '', '', '', '', 'background-color: red', '', '', '']
# ['background-color: green', '', '', '', '', '', '', 'background-color: green', '', '']
# ['', '', '', '', '', '', '', '', '', 'background-color: red']
# <style type="text/css">
# #T_c44a8_row0_col3, #T_c44a8_row2_col0, #T_c44a8_row5_col0, #T_c44a8_row6_col1, #T_c44a8_row7_col3, #T_c44a8_row9_col0, #T_c44a8_row9_col2 {
#   background-color: green;
# }
# #T_c44a8_row6_col0, #T_c44a8_row6_col2, #T_c44a8_row9_col1, #T_c44a8_row9_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_c44a8">
#   <thead>
#     <tr>
# ...

# %% [markdown]
# <h2>4.2</h2><br>
# <span style='font-size:18px;'>Вирахувати математичне сподівання та дисперсію для набору даних. Стандартизувати дані.</span>

# %% [markdown]
# $$
# \bar{X_{std}} = \frac{1}{\sigma} (X - \mu)
# $$
#
# $$
# \mu = \sum p_i X_i  {-де  p_i-ймовірність \hspace{0.25cm} появи \hspace{0.25cm} елементу X_i}
# $$
#
# $$
# \sigma = \sqrt{\frac{\sum_{}{} (X_i - \bar{X})}{n-1}}
# $$

# %%
# Обчислення математичного сподівання
# data.mean(numeric_only=True)
def calculate_mean(df):
    means = {}
    for col in df.columns:
        if pd.api.types.is_numeric_dtype(df[col]):
            n = len(df[col])
            sum_values = sum(df[col])
            mean_value = sum_values / n
            means[col] = mean_value
    return means
# print(calculate_mean(data))


# Обчислення дисперсії
#  variance_values = df.var()
def var(df):
    means = calculate_mean(df)
    var1 = {}
    for col in df.columns:
        if pd.api.types.is_numeric_dtype(df[col]):
            n = len(df[col])
            mean = means[col]
            var1[col] = sum((item - mean)**2 for item in df[col]) / (n - 1)
    return var1
# print(var(data))

#standardized_data = (data - mean_values) / np.sqrt(variance_values)
def standardized_data(df):
    means = calculate_mean(df)
    var1 = var(df)
    copy_df = df.copy()
    for col in df.columns:
        if pd.api.types.is_numeric_dtype(df[col]):
            df[col] = ((df[col] - means[col]) / np.sqrt(var1[col]))
            
    return df

standardized_data = standardized_data(df)

# %%
standardized_data
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar
# 0      -0.199166          0.000000     0.229902        1.742545
# 1      -1.128606          0.891133    -0.040571       -0.961160
# 2       1.261383          0.297044     0.770849       -0.210917
# 3       0.066389         -1.188177    -0.311044        0.015571
# 4       0.066389         -1.188177    -0.311044        0.015571
# 5       1.261383          0.297044     0.770849       -0.210917
# 6      -1.261383          1.485221    -2.474832       -0.196762
# 7      -0.199166          0.000000     0.229902        1.742545
# 8      -1.128606          0.891133    -0.040571       -0.961160
# 9       1.261383         -1.485221     1.176559       -0.975316

# %% [markdown]
# <h2>5</h2>
# <br>
# <span style='font-size:18px;'>Провести візуалізацію даних. Для цього необхідно побудувати такі типи графіків: Line Plot,
# Bare Chart, Histogram, Heatmap.</span>

# %%
sns.lineplot(standardized_data)
# Out:
# <Axes: >

# %%
sns.heatmap(standardized_data, annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(standardized_data, bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
plt.figure(figsize=(10,6))

sns.barplot(x=standardized_data.index, y = standardized_data['fixed acidity'], color='blue', label='fixed acidity')
sns.barplot(x=standardized_data.index, y = standardized_data['volatile acidity'], color='green', label='volatile acidity')
plt.show()

sns.barplot(x=standardized_data.index, y = standardized_data['citric acid'], color='red', label='citric acid')
sns.barplot(x=standardized_data.index, y = standardized_data['residual sugar'], color='purple', label='residual sugar')

plt.show()

# %% [markdown]
# <h2>6</h2> Збудувати лінійний графік з 4-ма лініями, які взяті з ознак та додати annotate для середнього
# значення кожної лінії. При цьому для візуалізації багатовимірних даних з кількістю ознак
# більше двох обов’язково необхідно за допомогою subplot збудувати 9 графіків за
# допомогою комбінування різних ознак.
#
# Туторіал по subplot та приклади - https://dev.to/thalesbruno/subplotting-with-matplotlib-and-seaborn-5ei8

# %%
fig, ax = plt.subplots(figsize=(14, 9))

x = data['alcohol']
y1 = data['pH']
y2 = data['sulphates']
y3 = data['fixed acidity']
y4 = data['quality']
colors = ['brown', 'green', 'blue', 'black']

lines = [y1, y2, y3, y4]
labels = ['pH', 'sulphates', 'fixed acidity', 'quality']

for line, label, color in zip(lines, labels, colors):
    mean_value = line.mean()
    max_sales_value = line.max()
    
    # Виводимо лінію
    sns.lineplot(x=x, y=line, label=label, color=color)
    
    # Додаємо анотацію для середнього значення
    plt.annotate(f'Mean {label} = {mean_value:.2f}', xy=(x.mean(), mean_value), color=color)


# Додаємо легенду та підписи до осей
plt.legend()
plt.xlabel('Alcohol')
plt.ylabel('Features')
# Out:
# Text(0, 0.5, 'Features')

# %%
line1 = data['pH']
line2 = data['sulphates']
line3 = data['alcohol']
line4 = data['density']
line5 = data['fixed acidity']
line6 = data['volatile acidity']
line7 = data['citric acid']
line8 = data['residual sugar']
line9 = data['chlorides']

Ox = data['type']

fig, axes = plt.subplots(3, 3, figsize=(15, 10), sharey=True, constrained_layout=True)
fig.suptitle('')

sns.barplot(ax=axes[0, 0], x=Ox, y=line1.values)
axes[0, 0].set_title(line1.name)

sns.barplot(ax=axes[0, 1], x=Ox, y=line2.values)
axes[0, 1].set_title(line2.name)

sns.barplot(ax=axes[0, 2], x=Ox, y=line3.values)
axes[0, 2].set_title(line3.name)

sns.barplot(ax=axes[1, 0], x=Ox, y=line4.values)
axes[1, 0].set_title(line4.name)

sns.barplot(ax=axes[1, 1], x=Ox, y=line5.values)
axes[1, 1].set_title(line5.name)

sns.barplot(ax=axes[1, 2], x=Ox, y=line6.values)
axes[1, 2].set_title(line6.name)

sns.barplot(ax=axes[2, 0], x=Ox, y=line7.values)
axes[2, 0].set_title(line7.name)

sns.barplot(ax=axes[2, 1], x=Ox, y=line8.values)
axes[2, 1].set_title(line8.name)

sns.barplot(ax=axes[2, 2], x=Ox, y=line9.values)
axes[2, 2].set_title(line9.name)

plt.show()

# %% [markdown]
# <h2>7.1</h2>Вирахувати коефіцієнт пірсона для кожної пари ознак.

# %%
corr_df = data.iloc[:, 1:].corr(method='pearson')
corr_df
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219366     0.323896
# volatile acidity           0.219366          1.000000    -0.377743
# citric acid                0.323896         -0.377743     1.000000
# residual sugar            -0.112557         -0.195953     0.142457
# chlorides                  0.298277          0.377234     0.039127
# free sulfur dioxide       -0.283065         -0.352402     0.133311
# total sulfur dioxide      -0.329627         -0.414417     0.195208
# density                    0.458723          0.271351     0.096320
# pH                        -0.251858          0.260505    -0.328909
# sulphates                  0.299921          0.225593     0.056594
# alcohol                   -0.095513         -0.038114    -0.010441
# quality                   -0.076833         -0.265774     0.085537
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# <h2>7.2</h2>

# %%
top_correlations = (corr_df.abs().stack()
                    .sort_values(ascending=False)
                    .reset_index()
                    .rename(columns={0: 'correlation'}))
#corr_df.abs().stack() сортує значення за спаданням, таким чином, найвищі абсолютні кореляції з'являються першими. 
#Параметр ascending=False забезпечує порядок за спаданням.
#.reset_index()  скидає індекс серії, перетворюючи його назад у DataFrame. DataFrame матиме стовпці для індексів рядків та стовпців, а також значення кореляції.

# За двома різними ознаками значеннями тому видаляємо дублікати
top_correlations = top_correlations.drop(top_correlations.index[:11])


top_3 = top_correlations.iloc[1:4, :3]
# Стоорюємо relplot
sns.relplot(data=data, x=data[top_3.iloc[0, 0]], y=data[top_3.iloc[0, 1]], hue=data['quality'])

# Show the plot
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# <h2>8</h2>У початковому наборі даних, перед заміною значень Nan на валідні значення за допомогою
# fillna, необхідно видалити всі колонки із значеннями Nan.

# %%
c_data = c_data.dropna()
c_data.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# <h2>9</h2>Видалити також випадкові значення з ознак що мають найбільшу кореляцію у кількості 10%
# для обох. Підрахувати кореляцію. Збудувати multipple scatterplot за допомогою FacetGrid
# для цих оновлених ознак використовуючи бібліотеку seaborn взявши третю ознаку за вісь x.

# %%
corr_df = c_data.corr(method="pearson", numeric_only=True)
top_correlations = (corr_df.abs().stack()
                    .sort_values(ascending=False)
                    .reset_index()
                    .rename(columns={0: 'correlation'}))
top_correlations = top_correlations.iloc[12:, :]
# Виберемо стовпці, які присутні в c_data
top_2 = top_correlations.iloc[0, :2].values

# Створимо копію для відфільтрованих даних
filtered_data = c_data.copy()

# Видалення 10% випадкових значень для вказаних ознак
for feature in top_2:
    mask = np.random.rand(len(filtered_data)) < 0.9
    filtered_data.loc[mask, feature] = np.nan

# Створення FacetGrid
g = sns.FacetGrid(filtered_data, col="quality", hue="type")
g.map(plt.scatter, selected_columns[0], selected_columns[1], alpha=0.7)
g.add_legend()

# Встановлення підписів для восьмого стовпця 
g.set_axis_labels(selected_columns[0], selected_columns[1])

# Відображення графіку
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# <span style="font-size:24px">Посилання:</span>
# <span style="font-size:18px">
#     <li>https://seaborn.pydata.org/</li>
#     <li>https://matplotlib.org/</li>
#     <li>https://numpy.org/</li>
#     <li>https://pandas.pydata.org/docs/user_guide/index.html#user-guide</li>
#     <li>https://medium.com/@shouke.wei/windows-python-developers-had-better-setup-earlier-iv-add-anaconda-powershell-on-windows-8942dd9cc1a</li>
# </span>
